# %%
import time

# %%
current=time.time()

# %%
current
# Out:
# 1626701397.2827675

# %%
new_current_gmtime=time.gmtime()
new_current_gmtime
# Out:
# time.struct_time(tm_year=2021, tm_mon=7, tm_mday=19, tm_hour=13, tm_min=29, tm_sec=57, tm_wday=0, tm_yday=200, tm_isdst=0)

# %%
current_epoch=time.gmtime(time.time())
current_epoch
# Out:
# time.struct_time(tm_year=2021, tm_mon=7, tm_mday=19, tm_hour=13, tm_min=29, tm_sec=58, tm_wday=0, tm_yday=200, tm_isdst=0)

# %%
current_gmtime=time.gmtime()
current_asctime=time.asctime(current_gmtime)

# %%
current_asctime()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e11f69ce86ee> in <module>
# ----> 1 current_asctime()
#
# TypeError: 'str' object is not callable

# %%
current_ctime=time.ctime()
print(current_ctime)
# Out:
# Mon Jul 19 19:00:32 2021

# %%
current_gmtime=time.gmtime()
current_asctime=time.asctime(current_gmtime)
print(current_asctime)
# Out:
# Mon Jul 19 13:31:49 2021

# %%
time.time()
# Out:
# 1626701592.563041

# %%
time.time()
# Out:
# 1626701596.5290117

# %%
time.time()
# Out:
# 1626701600.6262436

# %%
time.time()
# Out:
# 1626701604.5059826

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2021, tm_mon=7, tm_mday=19, tm_hour=13, tm_min=33, tm_sec=48, tm_wday=0, tm_yday=200, tm_isdst=0)

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2021, tm_mon=7, tm_mday=19, tm_hour=13, tm_min=33, tm_sec=53, tm_wday=0, tm_yday=200, tm_isdst=0)

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2021, tm_mon=7, tm_mday=19, tm_hour=13, tm_min=34, tm_sec=6, tm_wday=0, tm_yday=200, tm_isdst=0)

# %%
time.asctime()
# Out:
# 'Mon Jul 19 19:04:21 2021'

# %%
time.asctime()
# Out:
# 'Mon Jul 19 19:04:40 2021'

# %%
time.asctime()
# Out:
# 'Mon Jul 19 19:04:47 2021'

# %%
time.asctime(time.gmtime())
# Out:
# 'Mon Jul 19 13:35:01 2021'

# %%
time.ctime()
# Out:
# 'Mon Jul 19 19:06:21 2021'

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2021, 7, 19, 19, 7, 56, 725526)

# %%
datetime.datetime.now().hour
# Out:
# 19

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2021, tm_mon=7, tm_mday=19, tm_hour=13, tm_min=39, tm_sec=31, tm_wday=0, tm_yday=200, tm_isdst=0)

# %%
start=time.time()
time.sleep(5)
end=time.time()
diff=end-start
diff
# Out:
# 5.00970983505249

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2021, 7, 19, 19, 20, 51, 492187)

# %%
datetime.datetime.now().strftime("%a")
# Out:
# 'Mon'

# %%
datetime.datetime.now().strftime("%A")
# Out:
# 'Monday'

# %%
datetime.date.today()
# Out:
# datetime.date(2021, 7, 19)

# %%
#Print your age
current_date=datetime.datetime.now().date()
birth_date=datetime.date(1988,11,10)
print("Current year",current_date.year)
print("Birth year",birth_date.year)
print("Age is calculated as",current_date.year-birth_date.year)
# Out:
# Current year 2021
# Birth year 1988
# Age is calculated as 33

# %%
#Print its been how many months you are enrolled in Cestar college.
course_enrol_month=datetime.datetime(2021,5,10)
current_month=datetime.datetime.now()
print("Month of enrolment",current_month.month)
print("current_month",current_month)
print("It has been",current_month.month-course_enrol_month.month,"months since enrolment")
# Out:
# Month of enrolment 7
# current_month 2021-07-19 19:58:06.330337
# It has been 2 months since enrolment
